# %%
from IPython import display

# %% [markdown]
# ### Nivell 1

# %% [markdown]
# - Exercici 1
#
# Crea una base relacional d’exemple utilitzant un document de text o a mà. Dissenya-la perquè contingui les següents taules, i estableix les relacions que consideris necessàries entre elles:

# %% [markdown]
# Taules :
# -	Taula de compres (transaccions)
#
# -	Taula d’establiments
#
# -	Taula de treballadors
#
# -	Taula de clients
#
# -	Taula de productes
#
# -	Taula de tipus de productes

# %%
image_url = "tasca_1.JPG"
display.Image(image_url,height= 1000, width = 1000)

# %% [markdown]
# * Notes:
#  + la linea rallada es que m'he equivocat
#  + m'ha costat una mica diferenciar entre taula de productes i taula de tipus de productes.
#  + He pensat per exemple en diferents concesionaries que venen diferents tipus de vehicles.
#  + En la taula de compra, cada producte que es ven (cotxe,moto,furgoneta) té associat el seu producte_id corresponent.
#  + La taula de productes porta associat el nom de cada producte, amb el seu preu unitari i les unitats que estan disponibles.
#  + la taula de tipus de productes entra més en detall en els atributs o caracteristiques del vehicle en questió.

# %% [markdown]
# ### tipus de relacions

# %% [markdown]
# Defineix les propietats de les relacions (1:1, 1:n, n:n)

# %% [markdown]
# + relacions 1:1 :
# + Crec que totes les relacions que he realitzat en l'exemple anterior son 1:1
#
#  * El registre ID_ESTABLIMENT de la taula d'establiments esta relacionat unicament amb el registre ESTABLIMENT_ID de la taula de treballadors
#  * Taula de clients relacionada amb el registre ID_CLIENT amb la taula de compres mitjançant CLIENT_ID
#  * Taula de tipus de productes amb la taula de productes mitjançant la clau ID_TIPUS_PRODUCTE
#  * El registre de venedor_id a la Taula de compres amb el registre id_treballador a la taula de treballadors.
#
#
# + relacions 1:n :
#  * Si haguess incorporat per exemple dins la taula de compres el id_establiment, aleshores aquest registre a la taula d'establiments seria 1:n

# %% [markdown]
# + En aquest exemple en particular no he realitzat cap relació del tipus n:n.
#  + Aquest relació es caracteritza perqué Un registre d'una taula pot estar relacionat amb més d'un registre de l'altra taula i viceversa.

# %% [markdown]
# - Exercici 2
#
# Utilitza un programa de creació de diagrames entitat-relació com http://dia-installer.de per crear el diagrama.

# %%
image_url = "ER_S17T01_execici2.png"
display.Image(image_url,height= 1000, width = 1000)

# %% [markdown]
# - Exercici 3
#
# Utilitza el Workbench de MySQL per crear un model relacional.

# %%
image_url = "pantallazo_workbench_mysql_mff.png"
display.Image(image_url,height= 1000, width = 1000)

# %% [markdown]
# + el model d'aquest "pantallazo" està a fitxer Model_relacional_workbench_mysql.mwb adjunt al github
